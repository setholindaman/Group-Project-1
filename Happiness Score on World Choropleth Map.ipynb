# %%
import plotly
plotly.__version__
# Out:
# '3.7.1'

# %%
import plotly.plotly as py
import matplotlib.pyplot as plt
import pandas as pd

df_code = pd.read_csv('dataset/2014_world_gdp_with_codes.csv')
df_code = df_code.rename(index=str, columns={"COUNTRY": "Country"})

df_Happiness_score = pd.read_csv('dataset/2018.csv')
merge_df = pd.merge(df_code, df_Happiness_score , on="Country")
merge_df
# Out:
#                       Country  GDP (BILLIONS) CODE  Happiness Rank  \
# 0                 Afghanistan           21.71  AFG             145
# 1                     Albania           13.40  ALB             112
# 2                     Algeria          227.80  DZA              84
# 3                      Angola          131.40  AGO             142
# 4                   Argentina          536.20  ARG              29
# 5                     Armenia           10.88  ARM             129
# 6                   Australia         1483.00  AUS              10
# 7                     Austria          436.10  AUT              12
# 8                  Azerbaijan           77.91  AZE              87
# 9                     Bahrain           34.05  BHR              43
# 10                 Bangladesh          186.60  BGD             115
# 11                    Belarus           75.25  BLR              73
# 12                    Belgium          527.80  BEL              16
# 13                     Belize            1.67  BLZ              49
# 14                      Benin            9.24  BEN             136
# 15                     Bhutan            2.09  BTN              97
# 16                    Bolivia           34.08  BOL              62
# 17     Bosnia and Herzegovina           19.55  BIH              93
# 18                   Botswana           16.30  BWA             146
# 19                     Brazil         2244.00  BRA              28
# 20                   Bulgaria           55.08  BGR             100
# 21               Burkina Faso           13.38  BFA             121
# 22                    Burundi            3.04  BDI             156
# 23                   Cambodia           16.90  KHM             120
# 24                   Cameroon           32.16  CMR              99
# 25                     Canada         1794.00  CAN               7
# 26   Central African Republic            1.73  CAF             155
# 27                       Chad           15.84  TCD             131
# 28                      Chile          264.10  CHL              25
# 29                      China        10360.00  CHN              86
# ..                        ...             ...  ...             ...
# 118                  Slovenia           49.93  SVN              51
# 119                   Somalia            2.37  SOM              98
# 120              South Africa          341.20  ZAF             105
# 121               South Sudan           11.89  SSD             154
# 122                     Spain         1400.00  ESP              36
# 123                 Sri Lanka           71.57  LKA             116
# 124                     Sudan           70.03  SDN             137
# 125                    Sweden          559.10  SWE               9
# 126               Switzerland          679.00  CHE               5
# 127                     Syria           64.70  SYR             150
# 128                    Taiwan          529.50  TWN              26
# 129                Tajikistan            9.16  TJK              80
# 130                  Tanzania           36.62  TZA             153
# 131                  Thailand          373.80  THA              46
# 132                      Togo            4.84  TGO             139
# 133                   Tunisia           49.12  TUN             111
# 134                    Turkey          813.30  TUR              74
# 135              Turkmenistan           43.50  TKM              68
# 136                    Uganda           26.09  UGA             135
# 137                   Ukraine          134.90  UKR             138
# 138      United Arab Emirates          416.40  ARE              20
# 139            United Kingdom         2848.00  GBR              19
# 140             United States        17420.00  USA              18
# 141                   Uruguay           55.60  URY              31
# 142                Uzbekistan           63.08  UZB              44
# 143                 Venezuela          209.20  VEN             102
# 144                   Vietnam          187.80  VNM              95
# 145                     Yemen           45.45  YEM             152
# 146                    Zambia           25.61  ZMB             125
# 147                  Zimbabwe           13.74  ZWE             144
#
#      Happiness Score  Economy (GDP per Capita)  Health (Life Expectancy)  \
# 0              3.632                     0.332                     0.255
# 1              4.586                     0.916                     0.790
# 2              5.295                     0.979                     0.687
# 3              3.795                     0.730                     0.269
# 4              6.388                     1.073                     0.744
# 5              4.321                     0.816                     0.666
# 6              7.272                     1.340                     0.910
# 7              7.139                     1.341                     0.891
# 8              5.201                     1.024                     0.603
# 9              6.105                     1.338                     0.698
# 10             4.500                     0.532                     0.579
# 11             5.483                     1.039                     0.700
# 12             6.927                     1.324                     0.894
# 13             5.956                     0.807                     0.474
# 14             4.141                     0.378                     0.240
# 15             5.082                     0.796                     0.527
# 16             5.752                     0.751                     0.508
# 17             5.129                     0.915                     0.758
# 18             3.590                     1.017                     0.417
# 19             6.419                     0.986                     0.675
# 20             4.933                     1.054                     0.712
# 21             4.424                     0.314                     0.254
# 22             2.905                     0.091                     0.145
# 23             4.433                     0.549                     0.457
# 24             4.975                     0.535                     0.182
# 25             7.328                     1.330                     0.896
# 26             3.083                     0.024                     0.010
# 27             4.301                     0.358                     0.053
# 28             6.476                     1.131                     0.808
# 29             5.246                     0.989                     0.799
# ..               ...                       ...                       ...
# 118            5.948                     1.219                     0.856
# 119            4.982                     0.000                     0.115
# 120            4.724                     0.940                     0.330
# 121            3.254                     0.337                     0.177
# 122            6.310                     1.251                     0.965
# 123            4.471                     0.918                     0.672
# 124            4.139                     0.605                     0.312
# 125            7.314                     1.355                     0.913
# 126            7.487                     1.420                     0.927
# 127            3.462                     0.689                     0.539
# 128            6.441                     1.365                     0.857
# 129            5.358                     0.474                     0.598
# 130            3.303                     0.455                     0.381
# 131            6.072                     1.016                     0.707
# 132            3.999                     0.259                     0.253
# 133            4.592                     0.900                     0.690
# 134            5.483                     1.148                     0.686
# 135            5.636                     1.016                     0.517
# 136            4.161                     0.322                     0.237
# 137            4.103                     0.793                     0.609
# 138            6.774                     2.096                     0.670
# 139            6.814                     1.301                     0.883
# 140            6.886                     1.398                     0.819
# 141            6.379                     1.093                     0.771
# 142            6.096                     0.719                     0.605
# 143            4.806                     0.996                     0.657
# 144            5.103                     0.715                     0.702
# 145            3.355                     0.442                     0.343
# 146            4.377                     0.562                     0.295
# 147            3.692                     0.357                     0.248
#
#      Freedom
# 0      0.085
# 1      0.419
# 2      0.077
# 3      0.000
# 4      0.570
# 5      0.260
# 6      0.647
# 7      0.617
# 8      0.430
# 9      0.594
# 10     0.580
# 11     0.307
# 12     0.583
# 13     0.593
# 14     0.440
# 15     0.541
# 16     0.606
# 17     0.280
# 18     0.557
# 19     0.493
# 20     0.359
# 21     0.312
# 22     0.065
# 23     0.696
# 24     0.454
# 25     0.653
# 26     0.305
# 27     0.189
# 28     0.431
# 29     0.597
# ..       ...
# 118    0.633
# 119    0.674
# 120    0.516
# 121    0.112
# 122    0.449
# 123    0.585
# 124    0.016
# 125    0.659
# 126    0.660
# 127    0.088
# 128    0.418
# 129    0.503
# 130    0.481
# 131    0.637
# 132    0.434
# 133    0.271
# 134    0.324
# 135    0.417
# 136    0.450
# 137    0.163
# 138    0.284
# 139    0.533
# 140    0.547
# 141    0.625
# 142    0.724
# 143    0.133
# 144    0.618
# 145    0.244
# 146    0.503
# 147    0.406
#
# [148 rows x 8 columns]

# %%
data = [go.Choropleth(
    locations = merge_df['CODE'],
    z = merge_df['Happiness Score'],
    text = merge_df['Country'],
    colorscale = [
        [0, "rgb(150, 50, 50)"],
        [0.35, "rgb(40, 60, 190)"],
        [0.5, "rgb(70, 100, 245)"],
        [0.6, "rgb(90, 120, 245)"],
        [0.7, "rgb(106, 137, 247)"],
        [1, "rgb(220, 220, 220)"]
    ],
    autocolorscale = False,
    reversescale = True,
    marker = go.choropleth.Marker(
        line = go.choropleth.marker.Line(
            color = 'rgb(180,180,180)',
            width = 0.5
        )),
    colorbar = go.choropleth.ColorBar(
        title = 'Happiness Score'),
)]

layout = go.Layout(
    title = go.layout.Title(
        text = 'Happiness Around the World - 2018'
    ),
    geo = go.layout.Geo(
        showframe = False,
        showcoastlines = False,
        projection = go.layout.geo.Projection(
            type = 'equirectangular'
        )
    ),
    annotations = [go.layout.Annotation(
        x = 0.55,
        y = 0.1,
        xref = 'paper',
        yref = 'paper',
        text = 'Source: Group Project, Data Analytic BootCamp, University of Denver'
    )]
)

fig = go.Figure(data = data, layout = layout)
py.iplot(fig, filename = 'd3-world-map')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~memol73/12.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ##
