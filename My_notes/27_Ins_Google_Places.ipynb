# %%
# Dependencies
import requests
import json

# Google developer API key
from config import gkey

# %%
# geocoordinates, ie. the near me function on our phones
target_coordinates = "39.7392358, -104.990251"
target_search = "Chinese"
target_radius = 8000
target_type = "restaurant"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# print the response url, avoid doing for public github repos in order to avoid exposing key
print(response.url)
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=39.7392358%2C+-104.990251&keyword=Chinese&radius=8000&type=restaurant&key=AIzaSyA7zD0fC3vAoyhYpTGsXxOWRnKOgGZZAjQ

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CrQCKgEAAOIkcBkqY60utB524XjjMnePeKv_J4xbQMOmC_FvGnpoH_OZgZ3EGJDZs9IiHNKF2xNZMcSOtVdlLUEvQZHmoR7EWI4o583nFCbkqD1WWTankO9ZUOpbk5e2CTWk83F_BJkv8plaGb1gRCBtz8ByTaDRKJXsZefUBjKCDqNTNMbYF6_YDGjMdd9m1UpR-BECKINVy1nhLVkpHd44Zqck5YyeG4qJfOiOzvLB4X79pYH207Lu5iqgCMUMAYMqb5owMmTPlik4M22_1z-GUN4lZuYrXF-iHvbID4SB0aWUW1v87wJvzrJ_H3LYjXr1BR5EvnQ392o_3PtGMhKWMq-SO7rnvrS-NKlnwg1CzYpWzbap5m1BxJmBsZysqUYjnCCsS7ZSqLHxC6FJkyxQ0DU2EzASEHw0Ul1pF1-hCc00TXx3vr0aFDFBUxYzbkOEm6BnFpoWdPNCchVJ",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.7353602,
#                     "lng": -104.9560606
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.73660542989271,
#                         "lng": -104.9547102701073
#                     },
#                     "southwest": {
#                         "lat": 39.73390577010727,
#                         "lng": -104.9574099298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "e6b7ca3dca4e03dfe857cbd7959e9037ae310ec1",
#             "name": "Peter's Chinese Restaurant",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101696764219780312734/photos\">Mia Voss</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA4hoUZYfyCUM934DCKzG63qbTAQp6qG_zKdm7-fMRX4dBxzUEgrpyjAdtw9HlP6Z8iiLYouuxDtqRXOoOt1hB5RQcI5O7fgweQYA4Ab7Lr1PjE8r15vPUdkbqcG0b52FtEhBId0TtzKyvTvEVfloM9_vhGhSq17-mtEdun_DikZC3u-zd6ytJmw",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJi4r7LbF-bIcRiiEiL2UiiAs",
#             "plus_code": {
#                 "compound_code": "P2PV+4H Denver, Colorado",
#                 "global_code": "85FQP2PV+4H"
#             },
#             "price_level": 1,
#             "rating": 4.3,
#             "reference": "ChIJi4r7LbF-bIcRiiEiL2UiiAs",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 276,
#             "vicinity": "2609 12th Ave, Denver"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.7396766,
#                     "lng": -104.9605477
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.74118637989271,
#                         "lng": -104.9591835201073
#                     },
#                     "southwest": {
#                         "lat": 39.73848672010727,
#                         "lng": -104.9618831798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "a531548ec6fba7b864d5b25902582cdd5251fe92",
#             "name": "Grand China",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107950000723063907689/photos\">Crystal Collins</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA5Ute98i4dFAWNnU8GlSPFkRH_oLcNeVAfjhrtz5ECP8uWvqZVBTZpQt0RV6PeQRwMSqbmAUgzKqpNsqqfiLODxRLU2BfNtWgJLw6rZPjIwOe_uQGhRQRjyvoGZVaXHvMEhD7nBe1AYfYbIDAzkJQIlkOGhTuiGoJIh8ugTZKa4SyYAis0ykmMA",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJTytsDbV-bIcRYtgnAfPb5NY",
#             "plus_code": {
#                 "compound_code": "P2QQ+VQ Denver, Colorado",
#                 "global_code": "85FQP2QQ+VQ"
#             },
#             "price_level": 1,
#             "rating": 4.1,
#             "reference": "ChIJTytsDbV-bIcRYtgnAfPb5NY",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 239,
#             "vicinity": "2200 E Colfax Ave, Denver"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.740337,
#                     "lng": -104.9078826
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.74174832989272,
#                         "lng": -104.9065338201073
#                     },
#                     "southwest": {
#                         "lat": 39.73904867010728,
#                         "lng": -104.9092334798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "a4448e5be94561c28802af36ffe739a8eec3c924",
#             "name": "Yu Hong Chinese Restaurant",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115647413406035448563/photos\">Mustafa Elattrib Alatrab \u0645\u0635\u0637\u0641\u0649 \u0627\u0644\u0623\u062a\u0631\u0628</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAM3nPfbDzAjij1RhWWF_-sjiMyw3CVFLNsFpFbXP1borLZ1lwo_5eKUOdj7bh5I0GSJW-XxkZfH4Kt6zh1ZXkNaumiltg0z0FlHAhQW1uQfCzZ34l426ofg1AHI-wKdOVEhDpVwFRvZznmqqiRnFVvuiBGhRwJauJ4zIkwtbeCVlDFYhxMZ2U6Q",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJaWTK3cp-bIcRyzZURv-eiaY",
#             "plus_code": {
#                 "compound_code": "P3RR+4R Denver, Colorado",
#                 "global_code": "85FQP3RR+4R"
#             },
#             "price_level": 1,
#             "rating": 3.9,
#             "reference": "ChIJaWTK3cp-bIcRyzZURv-eiaY",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 126,
#             "vicinity": "6901 E Colfax Ave, Denver"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.711448,
#                     "lng": -104.980079
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.71273462989272,
#                         "lng": -104.9787324701073
#                     },
#                     "southwest": {
#                         "lat": 39.71003497010728,
#                         "lng": -104.9814321298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "57df35a59548093c7cb79d4d7a2ec6619d6c1a0d",
#             "name": "New China Cafe",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103723338446030602803/photos\">Ernie Ruiz</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAytUA9YjiyMT5PiQuJ7TT8MVR6npfiHGgE1aI7TO1M6FvSbpNWa1F2DY0IYcZOWQcoayCScz3oY9VW9G_9aJ4jRMCjlZscuqzVrvvIa44R5QuQf0Z1Z97xMIPTKrOWf_xEhBliHMHLeF8P8P1xSsw8LjBGhQDSegSCxH4LhlNWcP3fJfPJxzFJQ",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJvcQOeeN-bIcRzREF62EAfzE",
#             "plus_code": {
#                 "compound_code": "P269+HX Denver, Colorado",
#                 "global_code": "85FQP269+HX"
#             },
#             "price_level": 1,
#             "rating": 4.6,
#             "reference": "ChIJvcQOeeN-bIcRzREF62EAfzE",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 349,
#             "vicinity": "609 E Alameda Ave, Denver"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.74062079999999,
#                     "lng": -105.064533
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.74194707989272,
#                         "lng": -105.0632722701073
#                     },
#                     "southwest": {
#                         "lat": 39.73924742010728,
#                         "lng": -105.0659719298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "252956596a8c0053dfec5181c7525277d1782d3b",
#             "name": "Beijing Chinese Cafe",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110012238603978680812/photos\">bernadette espinoza</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAhVKZo_y3HDiGd01izQDFOdToSWkuxRTQ1Hy0fLABJRZziKEcc1DvkQiftCiGsqUYJoBfUBgVJPyD8cREaRgsB57L7usjXWWzWJn1_emy90Hv8Zt54hBv0TGZ-Vr5qCPiEhAoEvZl0mWerYOFDMy93lW_GhQQ7kt0tuplkQ1BMdODDFE1TKcGqQ",
#                     "width": 3120
#                 }
#             ],
#             "place_id": "ChIJN5xPADuHa4cRPlzthJhS4DI",
#             "plus_code": {
#                 "compound_code": "PWRP+65 Lakewood, Colorado",
#                 "global_code": "85FPPWRP+65"
#             },
#             "price_level": 1,
#             "rating": 4.3,
#             "reference": "ChIJN5xPADuHa4cRPlzthJhS4DI",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 204,
#             "vicinity": "6173 W Colfax Ave, Lakewood"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.739902,
#                     "lng": -104.9812487
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.74131272989272,
#                         "lng": -104.9798974201073
#                     },
#                     "southwest": {
#                         "lat": 39.73861307010728,
#                         "lng": -104.9825970798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "130c2c72708549098cded50ca1803247612a6f1b",
#             "name": "Great Wall Chinese Restaurant",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105865048815633447157/photos\">ahmed nagi</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA-VnQlQDS0dL9ygtZeKRHplJJXOnhtCsQXFwdPd0tlJ0ZbPVZHkI5uVUQxMW107jvrZCGhLGRQsOF0Ts4-eUj5qzO1mAdmjwzow28L9K9bSWoAq6yI2ABSRex7g118Ak-EhDnIaMEBdXALn8quL0iNI5tGhSC91wThba37MydTKByejHrflnM3w",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJT44bPyt5bIcReZb6itIMD5o",
#             "plus_code": {
#                 "compound_code": "P2Q9+XG Denver, Colorado",
#                 "global_code": "85FQP2Q9+XG"
#             },
#             "price_level": 1,
#             "rating": 3.8,
#             "reference": "ChIJT44bPyt5bIcReZb6itIMD5o",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 373,
#             "vicinity": "440 E Colfax Ave, Denver"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.7526832,
#                     "lng": -105.0011169
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.75388252989272,
#                         "lng": -104.9999726701073
#                     },
#                     "southwest": {
#                         "lat": 39.75118287010728,
#                         "lng": -105.0026723298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "9f434224a7fe1e0b894e14c1f6117d07d2513c38",
#             "name": "Zoe Ma Ma",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106921166248260409933/photos\">richard didonato</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAwdKx9r8H8haMTyo_fIczdquwoheO_DhaHB2UQciSmJUcOEjYqShNSXGnlAH1VMJ0I2fUl4v8YZt6VB9l20PLYDBpZDSrkWJggcxt6iIzKvhnEPWvLn1ppxCS6C29vtL1EhB5aY50u0HIMIw_uTzErvQQGhRinz_HuYdvLbB_0akdE89-azQSUg",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJX8jfmsN4bIcRzPAoW-4fsR0",
#             "plus_code": {
#                 "compound_code": "QX3X+3H Denver, Colorado",
#                 "global_code": "85FPQX3X+3H"
#             },
#             "price_level": 1,
#             "rating": 4.2,
#             "reference": "ChIJX8jfmsN4bIcRzPAoW-4fsR0",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 772,
#             "vicinity": "1625 Wynkoop St, Denver"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.709077,
#                     "lng": -104.987861
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.71036737989272,
#                         "lng": -104.9865557701073
#                     },
#                     "southwest": {
#                         "lat": 39.70766772010727,
#                         "lng": -104.9892554298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "d049effdb3843ee4f724180cbfda298e3ec2cfdd",
#             "name": "Imperial Chinese Seafood",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 5312,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102712903338265011116/photos\">Charlotte McLoughlin-Lamberton</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAfpiP0UehcdYCp_2moiDhVvOhixw7OmDxZVyxMFqaPIT--vnnefck_zd4jhLqpA-VBnog157rbQ54e_AGfIYkrKeoQzdHpnMnR2GEXo_Awa5tqMTUaGPhpVHxfd45dEihEhD32YQR2gEoDWabC0IOajvgGhSYog8qCxQozL6CjSFXVpFrEjj-SA",
#                     "width": 2988
#                 }
#             ],
#             "place_id": "ChIJ__a6Ih1_bIcRcSqp-eQd46U",
#             "plus_code": {
#                 "compound_code": "P256+JV Denver, Colorado",
#                 "global_code": "85FQP256+JV"
#             },
#             "price_level": 2,
#             "rating": 4,
#             "reference": "ChIJ__a6Ih1_bIcRcSqp-eQd46U",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_delivery",
#                 "bar",
#                 "meal_takeaway",
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 216,
#             "vicinity": "431 S Broadway, Denver"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.7492785,
#                     "lng": -104.9997302
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.75054997989272,
#                         "lng": -104.9981498701073
#                     },
#                     "southwest": {
#                         "lat": 39.74785032010728,
#                         "lng": -105.0008495298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "f79b5077fed44ba079d2c9af7b9b48eeb93a0280",
#             "name": "P.F. Chang's",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100018083500498576883/photos\">Git Stray</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAIW1AVJHr7wJzAfb-BJkubmLEvGfDMH-QF4U10sUunqL5kmSIr7r31JNsqpPFt8B5HyFGNtrJBmwlJ9tu8U6pYJlQdCKQ4AByh_eaS7WFm_wOema7yjh5o974Q9xbY7P1EhBHF9TlzU_kxmwyAj_DzCZ1GhQveaz4e-h2j3O6F7pLI5rn4VrMnQ",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJGyE7_cR4bIcRuzF0YptKk0E",
#             "plus_code": {
#                 "compound_code": "P2X2+P4 Denver, Colorado",
#                 "global_code": "85FQP2X2+P4"
#             },
#             "price_level": 2,
#             "rating": 4.1,
#             "reference": "ChIJGyE7_cR4bIcRuzF0YptKk0E",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 541,
#             "vicinity": "1415 15th St, Denver"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.7691335,
#                     "lng": -105.0542004
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.77046502989273,
#                         "lng": -105.0529485201073
#                     },
#                     "southwest": {
#                         "lat": 39.76776537010728,
#                         "lng": -105.0556481798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "d9c6fbb65508d690507603ed12fa08cd9788da8c",
#             "name": "Ho Mei Chinese Restaurant",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105735037846625410365/photos\">sheila hodges</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA0YEqrXOraDjTeHW6_cbzNyqANZFNMLmaKmb9Lpf8gvYO2EPmeu8i6fV0VD_Ykmw3sHU0UvOtYSaatR-08UHKua-aBV9pJRmC9MdwETU_APCedlOjQBxS-QbCuKocHGMUEhAOleale4s9ReUyTTH_-z-cGhRk25cXEj9i5WPgCzPZBBfaYGWdug",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJofPiZ3WHa4cRBduB2fRs6dw",
#             "plus_code": {
#                 "compound_code": "QW9W+M8 Wheat Ridge, Colorado",
#                 "global_code": "85FPQW9W+M8"
#             },
#             "price_level": 1,
#             "rating": 3.9,
#             "reference": "ChIJofPiZ3WHa4cRBduB2fRs6dw",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 313,
#             "vicinity": "5280 W 38th Ave, Wheat Ridge"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.7698088,
#                     "lng": -105.0026968
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.77108262989272,
#                         "lng": -105.0011954201073
#                     },
#                     "southwest": {
#                         "lat": 39.76838297010728,
#                         "lng": -105.0038950798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "f0a940b1a2fa82f24726fdd56f8ccf655ae73bb8",
#             "name": "China Dragon",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118206246771640510886/photos\">Vanessa Gomez</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAryFgvdj4Zc9k7mf_oy4WuXU64HxF4f931fExAgbXGZJZuotXY_QWtEL3pgGlG3rDFBtJkwIh69lQFKgyaZoHPpt3R_zYTydJkVRx1YKj0oPzgm97SP0rqCM2G8s0pKyVEhBtx-4DauLEk_pqfe148QlfGhQP_6yftR3UW7lW13veDE_dMzJ7Hg",
#                     "width": 3120
#                 }
#             ],
#             "place_id": "ChIJnz9YZPF4bIcR1f6g6Nco6OQ",
#             "plus_code": {
#                 "compound_code": "QX9W+WW Denver, Colorado",
#                 "global_code": "85FPQX9W+WW"
#             },
#             "price_level": 1,
#             "rating": 3.8,
#             "reference": "ChIJnz9YZPF4bIcR1f6g6Nco6OQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 124,
#             "vicinity": "2614, 1329 W 38th Ave, Denver"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.7106656,
#                     "lng": -105.0772521
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.71204587989271,
#                         "lng": -105.0757059201073
#                     },
#                     "southwest": {
#                         "lat": 39.70934622010727,
#                         "lng": -105.0784055798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "5b47f88862a2db1cd455e37ba89f584fbcf7d601",
#             "name": "P.F. Chang's",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111574963341435950484/photos\">Kent Campbell</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAnmcjCrtrs-vrYEHRto-eVyNIPWze2FMEAeP-egtUWBOsaKv1AfROITMi5UsFXggvB_xljzMOvsUGmmqBQPsRLVl_GCoV_NmK7JlztQkXEAQwbDRQrKUYXPQ4vvCqAwtFEhCSK8PBdYgwTQSZtSpe6sbeGhRk3CVYpJ4QK4y3EyCp6c1z0ZBsTQ",
#                     "width": 3840
#                 }
#             ],
#             "place_id": "ChIJj514rSCBa4cRn1UBXj-8nqU",
#             "plus_code": {
#                 "compound_code": "PW6F+73 Lakewood, Colorado",
#                 "global_code": "85FPPW6F+73"
#             },
#             "price_level": 2,
#             "rating": 4.1,
#             "reference": "ChIJj514rSCBa4cRn1UBXj-8nqU",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 400,
#             "vicinity": "7210 W Alameda Ave, Lakewood"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.679481,
#                     "lng": -104.9597938
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.68090242989271,
#                         "lng": -104.9584421201073
#                     },
#                     "southwest": {
#                         "lat": 39.67820277010727,
#                         "lng": -104.9611417798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "a23a40fe91f084b8da3125dc32557e7be2241aee",
#             "name": "Yum Yum Spice",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113350017023654845978/photos\">Michael Yang</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAlW23FGH6fg9UP2KFjD1Wlk9oMDxEZ2BjqShkTBBgzVUTEsNgRFoterhltz6wYeu2Tdv0HNZekXwO9uj8CmPkWcUbu9XjFbO6e5f3YTMLVGLAjQ_71fi3Qo_AHLAUc1UIEhBEAwCvttvtFYDDxt8JL9EjGhQe6gx2fr-chFoBHLLcE-Lot8O-gg",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJN-USGxV-bIcRlQk8u03ZKb0",
#             "plus_code": {
#                 "compound_code": "M2HR+Q3 Denver, Colorado",
#                 "global_code": "85FQM2HR+Q3"
#             },
#             "price_level": 2,
#             "rating": 4.3,
#             "reference": "ChIJN-USGxV-bIcRlQk8u03ZKb0",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 165,
#             "vicinity": "4318, 2039 S University Blvd, Denver"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.7155268,
#                     "lng": -104.9523811
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.71684932989272,
#                         "lng": -104.9512743201073
#                     },
#                     "southwest": {
#                         "lat": 39.71414967010728,
#                         "lng": -104.9539739798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "77aa28f6469beb47133723fe9d37e53a92ed72ee",
#             "name": "Panda Express",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101696764219780312734/photos\">Mia Voss</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAvvl4U58bzzwOCn7nXCB1E9253b__wRcyu_tXGYo876HnwIVyV4ZVwzjkFTqZwyZUKs9t5tT9A5WRj8yZBwfA3dNaI_II0i-_5o-Ixy6ohEGAoPjDB9ISCtNY8HDVq1EbEhBQisvuCjoww1Zs0iC9U_xoGhSBpuJnUBNDNUK5ia9H4xbJq021nA",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJX4Jmj5B-bIcRXWmsHgQ8Yvw",
#             "plus_code": {
#                 "compound_code": "P28X+62 Denver, Colorado",
#                 "global_code": "85FQP28X+62"
#             },
#             "price_level": 1,
#             "rating": 3.7,
#             "reference": "ChIJX4Jmj5B-bIcRXWmsHgQ8Yvw",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 106,
#             "vicinity": "3000 E 1st Ave #111, Denver"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.690186,
#                     "lng": -105.053654
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.69153592989272,
#                         "lng": -105.0522045201073
#                     },
#                     "southwest": {
#                         "lat": 39.68883627010727,
#                         "lng": -105.0549041798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "25ac6132898950cec0f8cb448e55c1acf85e46e6",
#             "name": "135 Chinese Restaurant",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102159444684313659753/photos\">Michelle Salvador</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA7XiFXO1k1zfrodoBxHgGCrqB19ujxaEki-qsdhS5wleB_vsS4uLRbs1XVAC-pDStEx81AIndd7ss7CqU_h11OSczhp-6GsBAZlPBTfhCKIm-1RwsLeY0BqlibSTwDU8_EhA2ZAQHPpI0UovV8-4Zt53uGhQcXBPVrAepRYSMPI76Dd0NDhCbuA",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJhbqmjoqAa4cRfdhPeYtE0xA",
#             "plus_code": {
#                 "compound_code": "MWRW+3G Lakewood, Colorado",
#                 "global_code": "85FPMWRW+3G"
#             },
#             "price_level": 1,
#             "rating": 4.2,
#             "reference": "ChIJhbqmjoqAa4cRfdhPeYtE0xA",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 182,
#             "vicinity": "1475 S Sheridan Blvd, Lakewood"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.7662673,
#                     "lng": -104.9000583
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.76761622989272,
#                         "lng": -104.8987085201073
#                     },
#                     "southwest": {
#                         "lat": 39.76491657010728,
#                         "lng": -104.9014081798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "4ee0e6b70d04132f04fc3a119a45eff73e2e590c",
#             "name": "Taste of Asia",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3264,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113287578757227469613/photos\">Jiankai Sun</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAJo7qgFobPy-5PS0U_DIYH0bDzPpM2jFP7isEK2IOzEtH5MdBEx6cKAEdrul6a32hLJdna8elkpQtimP8Is3GMKKCntd2qOCGX-iBzEvRGu5F9wrbBLCp0uImel3r0R8rEhDB8NFHmuVcDc2NfDBfyU_2GhT1eTrF5pIB-k-gQbi91sq5bZIfbQ",
#                     "width": 2448
#                 }
#             ],
#             "place_id": "ChIJFacQE5l7bIcRZ2_yQKdO1C0",
#             "plus_code": {
#                 "compound_code": "Q38X+GX Denver, Colorado",
#                 "global_code": "85FQQ38X+GX"
#             },
#             "price_level": 2,
#             "rating": 3,
#             "reference": "ChIJFacQE5l7bIcRZ2_yQKdO1C0",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 144,
#             "vicinity": "7505 E 35th Ave, Denver"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.7643251,
#                     "lng": -104.973233
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.76567502989272,
#                         "lng": -104.9719416701073
#                     },
#                     "southwest": {
#                         "lat": 39.76297537010728,
#                         "lng": -104.9746413298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "71ed6436afc48570bdef299ec250c2fd6ae99636",
#             "name": "Ho Ho Chinese Restaurant",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108166285476051214278/photos\">Meghan Victoria</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAsiVYIvv9BvyyEIjuiZhSAij_8nbyRk4HzKh9Ncy7UG_EHENdAF-mkFYt09EDRwlWHytvl2Ni9vc6y9i6c6YTltl50QAxLK_ZYr_10S5uX8N6yedbhBiM3r-qIBLgPW9YEhDJRJVkAg8wmU5NkcqT9FJbGhSSaHQsSqLmUq7ADUhbzTQfm7KnHQ",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJYZtiWxd5bIcRqXJI0sXJCxk",
#             "plus_code": {
#                 "compound_code": "Q27G+PP Denver, Colorado",
#                 "global_code": "85FQQ27G+PP"
#             },
#             "price_level": 1,
#             "rating": 4.1,
#             "reference": "ChIJYZtiWxd5bIcRqXJI0sXJCxk",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 99,
#             "vicinity": "3350 N Downing St, Denver"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.74942,
#                     "lng": -105.012474
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.75076982989271,
#                         "lng": -105.0111241701073
#                     },
#                     "southwest": {
#                         "lat": 39.74807017010727,
#                         "lng": -105.0138238298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "8ab6587355ed3a41795903193dbdd0d660e6b00f",
#             "name": "Panda Express",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108378807870376584518/photos\">joe Barmada</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAGuBOacHX1ZZXQFNVuNtlfIpD2dvrFULtIvGcZLMb7Cl7bzrvAI5z1762It6F2VGm41AtcO-YehF_VJvDITwF68yenElPbX7PfmQ1kWVQRnDxJlldGr28Pwbaz6BN-q53EhA2x1miciU_Nozvx6JOpj8hGhQglQpkLhp2PERPxCvSsXow9nV1cw",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJhZKKY794bIcRJ_9ue0LvPU8",
#             "plus_code": {
#                 "compound_code": "PXXQ+Q2 Denver, Colorado",
#                 "global_code": "85FPPXXQ+Q2"
#             },
#             "price_level": 1,
#             "rating": 3.5,
#             "reference": "ChIJhZKKY794bIcRJ_9ue0LvPU8",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_takeaway",
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 28,
#             "vicinity": "ELITCH GARDENS THEME PARK, 2000, Elitch Cir, Denver"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.802302,
#                     "lng": -105.0801426
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.80350642989272,
#                         "lng": -105.0788073201073
#                     },
#                     "southwest": {
#                         "lat": 39.80080677010728,
#                         "lng": -105.0815069798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "2cac0e1700a025a399cc3a588cdded386a155308",
#             "name": "135 Chinese Restaurant",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116064667466079138623/photos\">Zachariah Handran</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAHY-pj0FI7ETpLS-88-UoCPl-xnVWUljhCiSFlQY_v27VfRZWVM_lUkuL5LJaXK0tMkukEaiBUCmQSQ59vSYPcpWoP02aGFUAGfLvzcv_Gyua2mUW5Y9PN8T3RXkboDL_EhBFDIuEmEuWv-1MXqHsYsP7GhQpFNY5uvmmmeFr-UKHOQ4XZ0o65g",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJreGgQyuGa4cR_wNOKDOP0Uw",
#             "plus_code": {
#                 "compound_code": "RW29+WW Arvada, Colorado",
#                 "global_code": "85FPRW29+WW"
#             },
#             "price_level": 1,
#             "rating": 4,
#             "reference": "ChIJreGgQyuGa4cR_wNOKDOP0Uw",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 227,
#             "vicinity": "7501 Ralston Rd, Arvada"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.6767663,
#                     "lng": -104.9146819
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.67811232989273,
#                         "lng": -104.9131782701073
#                     },
#                     "southwest": {
#                         "lat": 39.67541267010728,
#                         "lng": -104.9158779298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "e7291dd1722a67dfe589050e7f0c1b40f4ad332b",
#             "name": "Chen's Garden",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115555130821591387652/photos\">Daniel Dossey</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA34MqxQTBDcGtQi6bmm4NBvMsedyyGCal656m7v0NKTg2lMvXYi2Z5KwHjoOImuqzUjrafHU32kjCTm08ygpM1u5K8OdDgc-5_6NHWv90Ag2gK8tgkLTmxXSud4Kl0f1REhC6Lya6B8zxCVQr799uD9syGhRRB1wQbfNYOGmJPbVJrTO1JMVnNA",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJRSR9C419bIcRvR69_H2WgVQ",
#             "plus_code": {
#                 "compound_code": "M3GP+P4 Denver, Colorado",
#                 "global_code": "85FQM3GP+P4"
#             },
#             "rating": 4,
#             "reference": "ChIJRSR9C419bIcRvR69_H2WgVQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 76,
#             "vicinity": "#107, 5848, 2243 S Monaco Pkwy, Denver"
#         }
#     ],
#     "status": "OK"
# }

# %%
# Print the name and address of the first restaurant that appears
print(places_data["results"][4]["name"])
print(places_data["results"][4]["vicinity"])
# Out:
# Beijing Chinese Cafe
# 6173 W Colfax Ave, Lakewood
